# %% [markdown]
# # Exercícios

# %% [markdown]
# ## 1. Criando um mini sistema de controle de estoque
#
# - Crie um sistema para ser usado pelo time de controle de estoque de um centro de distribuição.
# - Imagine que ao fim de todo dia, o time conta quantas unidades de produto existem no estoque. Se tivermos um estoque abaixo do estoque permitido para aquela categoria do produto, o time deve ser avisado (print) para fazer um novo pedido daquele produto.
# - Cada categoria de produto tem um estoque mínimo diferente, segundo a regra abaixo:
#
# - alimentos -> Estoque mínimo: 50
# - bebidas -> Estoque mínimo: 75
# - limpeza -> Estoque mínimo: 30
#
# Para isso vamos criar um programa que pede 3 inputs do usuário: nome do produto, categoria e quantidade atual em estoque.
#
# Se o produto tiver abaixo do estoque mínimo da categoria dele, o programa deve printar a mensagem "Solicitar {produto} à equipe de compras, temos apenas {unidades} em estoque"
#
# Exemplo: Se o usuário preenche os inputs com: bebidas, dolly, 90, o programa não deve exibir nenhuma mensagem.<br>
# Agora, se o usuário preenche os inputs com: bebidas, guaraná, 60, o programa deve exibir a mensagem "Solicitar guaraná à equipe de compras, temos apenas 60 unidades em estoque.
#
# Obs: lembre de usar o int() para transformar o número inserido pelo usuário no input de string para int.<br>
# Obs2: Caso o usuário não preencha alguma das 3 informações, o programa deve exibir uma mensagem para avisá-lo de preencher corretamente.

# %%
#seu código aqui
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Solicita as informações do usuário
produto = input('Digite o nome do produto: ')
categoria = input('Digite a categoria do produto: ')
quantidade = input('Digite a quantidade atual em estoque: ')

# Verifica se todas as informações foram preenchidas
if not produto or not categoria or not quantidade:
    print('Por favor, preencha todas as informações corretamente.')
else:
    # Converte a quantidade para int
    quantidade = int(quantidade)
    

    # Verifica se a categoria do produto está no dicionário de estoque mínimo
    if categoria in estoque_minimo:
        # Verifica se a quantidade está abaixo do estoque mínimo
        if quantidade < estoque_minimo[categoria]:
            print(f'Solicitar {produto} à equipe de compras, temos apenas {quantidade} unidades em estoque')
    else:
        print('Categoria de produto desconhecida. Por favor, verifique e tente novamente.')
# Out:
# Digite o nome do produto:  a
# Digite a categoria do produto:  a
# Digite a quantidade atual em estoque:  a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 18
#      15     print('Por favor, preencha todas as informações corretamente.')
#      16 else:
#      17     # Converte a quantidade para int
# ---> 18     quantidade = int(quantidade)
#      21     # Verifica se a categoria do produto está no dicionário de estoque mínimo
#      22     if categoria in estoque_minimo:
#      23         # Verifica se a quantidade está abaixo do estoque mínimo
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

while True:
    # Solicita as informações do usuário
    produto = input('Digite o nome do produto (ou "sair" para terminar): ')
    if produto.lower() == 'sair':
        break

    categoria = input('Digite a categoria do produto: ')
    quantidade = input(f'Quantidade atual em estoque {produto}: ')

    # Verifica se todas as informações foram preenchidas
    if not produto or not categoria or not quantidade:
        print('Por favor, preencha todas as informações corretamente.')
    else:
        # Converte a quantidade para int
        quantidade = int(quantidade)

        # Verifica se a categoria do produto está no dicionário de estoque mínimo
        if categoria in estoque_minimo:
            # Verifica se a quantidade está abaixo do estoque mínimo
            if quantidade < estoque_minimo[categoria]:
                print(f'Solicitar {produto} à equipe de compras, temos apenas {quantidade} unidades em estoque')
        else:
            print('Categoria de produto desconhecida. Por favor, verifique e tente novamente.')
# Out:
# Digite o nome do produto (ou "sair" para terminar):  sair

# %%
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')
        quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

        # Verifica se todas as informações foram preenchidas
        if not produto or not categoria or not quantidade:
            print('Por favor, preencha todas as informações corretamente.')
        else:
            # Converte a quantidade para int e adiciona ao estoque
            quantidade = int(quantidade)
            estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade

            # Verifica se a quantidade está abaixo do estoque mínimo
            if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
                print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Solicita o nome do produto
        produto = input('Digite o nome do produto que deseja verificar: ')

        # Exibe a quantidade em estoque
        if produto in estoque_atual:
            print(f'O estoque atual de {produto} é {estoque_atual[produto]} unidades')
        else:
            print('Produto não encontrado no estoque.')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')
        quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

        # Verifica se todas as informações foram preenchidas
        if not produto or not categoria or not quantidade:
            print('Por favor, preencha todas as informações corretamente.')
        else:
            # Converte a quantidade para int e adiciona ao estoque
            quantidade = int(quantidade)
            estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade

            # Verifica se a quantidade está abaixo do estoque mínimo
            if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
                print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade |')
        print('|---------|------------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')
        quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

        # Verifica se todas as informações foram preenchidas
        if not produto or not categoria or not quantidade:
            print('Por favor, preencha todas as informações corretamente.')
            continue

        # Verifica se a quantidade pode ser convertida em um inteiro
        try:
            quantidade = int(quantidade)
        except ValueError:
            print('Quantidade inválida. Por favor, insira um número inteiro.')
            continue

        # Adiciona a quantidade ao estoque
        estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade

        # Verifica se a quantidade está abaixo do estoque mínimo
        if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade |')
        print('|---------|------------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  adicionar
# Digite o nome do produto:  agua
# Digite a categoria do produto:  alimentos
# Digite a quantidade a ser adicionada ao estoque:  200
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  adicionar
# Digite o nome do produto:  cerveja
# Digite a categoria do produto:  bebidas
# Digite a quantidade a ser adicionada ao estoque:  300
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  estoque
# | Produto | Quantidade |
# |---------|------------|
# | agua | 200 |
# | cerveja | 300 |
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  adicionar
# Digite o nome do produto:  agua
# Digite a categoria do produto:  alimento
# Digite a quantidade a ser adicionada ao estoque:  30
# ...

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

# Dicionário para armazenar a categoria de cada produto
categorias_produto = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')
        quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

        # Verifica se todas as informações foram preenchidas
        if not produto or not categoria or not quantidade:
            print('Por favor, preencha todas as informações corretamente.')
            continue

        # Verifica se a quantidade pode ser convertida em um inteiro
        try:
            quantidade = int(quantidade)
        except ValueError:
            print('Quantidade inválida. Por favor, insira um número inteiro.')
            continue

        # Verifica se o produto já tem uma categoria e se é diferente da informada
        if produto in categorias_produto and categorias_produto[produto] != categoria:
            print(f'O produto {produto} já está cadastrado na categoria {categorias_produto[produto]}. Não é possível cadastrá-lo em outra categoria.')
            continue

        # Adiciona a quantidade ao estoque e associa o produto à categoria
        estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade
        categorias_produto[produto] = categoria

        # Verifica se a quantidade está abaixo do estoque mínimo
        if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade | Categoria |')
        print('|---------|------------|-----------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} | {categorias_produto[produto]} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

# Dicionário para armazenar a categoria de cada produto
categorias_produto = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')
        quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

        # Verifica se todas as informações foram preenchidas
        if not produto or not categoria or not quantidade:
            print('Por favor, preencha todas as informações corretamente.')
            continue

        # Verifica se a quantidade pode ser convertida em um inteiro
        try:
            quantidade = int(quantidade)
        except ValueError:
            print('Quantidade inválida. Por favor, insira um número inteiro.')
            continue

        # Se o produto já existe, usa a categoria existente
        if produto in categorias_produto:
            categoria = categorias_produto[produto]
            print(f'O produto {produto} já está cadastrado na categoria {categoria}. Adicionando à categoria existente.')

        # Adiciona a quantidade ao estoque e associa o produto à categoria
        estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade
        categorias_produto[produto] = categoria

        # Verifica se a quantidade está abaixo do estoque mínimo
        if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade | Categoria |')
        print('|---------|------------|-----------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} | {categorias_produto[produto]} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

# Dicionário para armazenar a categoria de cada produto
categorias_produto = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')
        quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

        # Verifica se todas as informações foram preenchidas
        if not produto or not categoria or not quantidade:
            print('Por favor, preencha todas as informações corretamente.')
            continue

        # Verifica se a quantidade pode ser convertida em um inteiro
        try:
            quantidade = int(quantidade)
        except ValueError:
            print('Quantidade inválida. Por favor, insira um número inteiro.')
            continue

        # Se o produto já existe, pergunta ao usuário se ele deseja adicionar na categoria existente
        if produto in categorias_produto and categorias_produto[produto] != categoria:
            resposta = input(f'O produto {produto} já está cadastrado na categoria {categorias_produto[produto]}. Deseja adicionar à categoria existente? (s/n) ')
            if resposta.lower() != 's':
                print('Produto não adicionado. Tente novamente.')
                continue

        # Adiciona a quantidade ao estoque e associa o produto à categoria
        estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade
        categorias_produto[produto] = categoria

        # Verifica se a quantidade está abaixo do estoque mínimo
        if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade | Categoria |')
        print('|---------|------------|-----------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} | {categorias_produto[produto]} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  adicionar
# Digite o nome do produto:  manga
# Digite a categoria do produto:  alimento
# Digite a quantidade a ser adicionada ao estoque:  50
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  adicionar
# Digite o nome do produto:  manga
# Digite a categoria do produto:  limpeza
# Digite a quantidade a ser adicionada ao estoque:  50
# O produto manga já está cadastrado na categoria alimento. Deseja adicionar à categoria existente? (s/n)  s
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  estoque
# | Produto | Quantidade | Categoria |
# |---------|------------|-----------|
# | manga | 100 | limpeza |
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

# Dicionário para armazenar a categoria de cada produto
categorias_produto = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')
        quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

        # Verifica se todas as informações foram preenchidas
        if not produto or not categoria or not quantidade:
            print('Por favor, preencha todas as informações corretamente.')
            continue

        # Verifica se a quantidade pode ser convertida em um inteiro
        try:
            quantidade = int(quantidade)
        except ValueError:
            print('Quantidade inválida. Por favor, insira um número inteiro.')
            continue

        # Se o produto já existe, usa a categoria existente
        if produto in categorias_produto:
            print(f'O produto {produto} já está cadastrado na categoria {categorias_produto[produto]}. Adicionando à categoria existente.')
            categoria = categorias_produto[produto]

        # Adiciona a quantidade ao estoque e associa o produto à categoria
        estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade
        categorias_produto[produto] = categoria

        # Verifica se a quantidade está abaixo do estoque mínimo
        if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade | Categoria |')
        print('|---------|------------|-----------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} | {categorias_produto[produto]} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  manga
# Ação desconhecida. Por favor, tente novamente.
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  alimentos
# Ação desconhecida. Por favor, tente novamente.
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  adicionar
# Digite o nome do produto:  manga
# Digite a categoria do produto:  alimentos
# Digite a quantidade a ser adicionada ao estoque:  manga
# Quantidade inválida. Por favor, insira um número inteiro.
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

# Dicionário para armazenar a categoria de cada produto
categorias_produto = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')

        while True:
            quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

            # Verifica se a quantidade pode ser convertida em um inteiro
            try:
                quantidade = int(quantidade)
                break
            except ValueError:
                print('Quantidade inválida. Por favor, insira um número inteiro.')

        # Se o produto já existe, usa a categoria existente
        if produto in categorias_produto:
            print(f'O produto {produto} já está cadastrado na categoria {categorias_produto[produto]}. Adicionando à categoria existente.')
            categoria = categorias_produto[produto]

        # Adiciona a quantidade ao estoque e associa o produto à categoria
        estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade
        categorias_produto[produto] = categoria

        # Verifica se a quantidade está abaixo do estoque mínimo
        if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade | Categoria |')
        print('|---------|------------|-----------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} | {categorias_produto[produto]} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

# Dicionário para armazenar a categoria de cada produto
categorias_produto = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')
        categoria = input('Digite a categoria do produto: ')

        # Verifica se a categoria inserida é válida
        if categoria not in estoque_minimo:
            print('Categoria inválida. As categorias válidas são: alimentos, bebidas, limpeza.')
            continue

        while True:
            quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

            # Verifica se a quantidade pode ser convertida em um inteiro
            try:
                quantidade = int(quantidade)
                break
            except ValueError:
                print('Quantidade inválida. Por favor, insira um número inteiro.')

        # Se o produto já existe, usa a categoria existente
        if produto in categorias_produto:
            print(f'O produto {produto} já está cadastrado na categoria {categorias_produto[produto]}. Adicionando à categoria existente.')
            categoria = categorias_produto[produto]

        # Adiciona a quantidade ao estoque e associa o produto à categoria
        estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade
        categorias_produto[produto] = categoria

        # Verifica se a quantidade está abaixo do estoque mínimo
        if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade | Categoria |')
        print('|---------|------------|-----------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} | {categorias_produto[produto]} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  adcionar
# Ação desconhecida. Por favor, tente novamente.
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  Adicionar
# Digite o nome do produto:  manga
# Digite a categoria do produto:  alimento
# Categoria inválida. As categorias válidas são: alimentos, bebidas, limpeza.
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
# Dicionário para armazenar o estoque mínimo para cada categoria
estoque_minimo = {
    'alimentos': 50,
    'bebidas': 75,
    'limpeza': 30
}

# Dicionário para armazenar o estoque atual
estoque_atual = {}

# Dicionário para armazenar a categoria de cada produto
categorias_produto = {}

while True:
    # Solicita a ação do usuário
    acao = input('Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar: ')
    if acao.lower() == 'sair':
        break
    elif acao.lower() == 'adicionar':
        # Solicita as informações do produto
        produto = input('Digite o nome do produto: ')

        while True:
            categoria = input('Digite a categoria do produto: ')

            # Verifica se a categoria inserida é válida
            if categoria not in estoque_minimo:
                print('Categoria inválida. As categorias válidas são: alimentos, bebidas, limpeza.')
            else:
                break

        while True:
            quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')

            # Verifica se a quantidade pode ser convertida em um inteiro
            try:
                quantidade = int(quantidade)
                break
            except ValueError:
                print('Quantidade inválida. Por favor, insira um número inteiro.')

        # Se o produto já existe, usa a categoria existente
        if produto in categorias_produto:
            print(f'O produto {produto} já está cadastrado na categoria {categorias_produto[produto]}. Adicionando à categoria existente.')
            categoria = categorias_produto[produto]

        # Adiciona a quantidade ao estoque e associa o produto à categoria
        estoque_atual[produto] = estoque_atual.get(produto, 0) + quantidade
        categorias_produto[produto] = categoria

        # Verifica se a quantidade está abaixo do estoque mínimo
        if estoque_atual[produto] < estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {estoque_atual[produto]} unidades em estoque')
    elif acao.lower() == 'estoque':
        # Exibe o estoque atual em uma tabela
        print('| Produto | Quantidade | Categoria |')
        print('|---------|------------|-----------|')
        for produto, quantidade in estoque_atual.items():
            print(f'| {produto} | {quantidade} | {categorias_produto[produto]} |')
    else:
        print('Ação desconhecida. Por favor, tente novamente.')
# Out:
# Digite "adicionar" para adicionar um produto, "estoque" para verificar o estoque ou "sair" para terminar:  sair

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque = {}
        self.vendas = 0

    def adicionar_produto(self, produto, quantidade):
        if produto in self.estoque:
            self.estoque[produto] += quantidade
        else:
            self.estoque[produto] = quantidade
        print(f'Adicionado {quantidade} de {produto} ao estoque.')

    def remover_produto(self, produto, quantidade):
        if produto in self.estoque and self.estoque[produto] >= quantidade:
            self.estoque[produto] -= quantidade
            print(f'Removido {quantidade} de {produto} do estoque.')
        else:
            print(f'Não foi possível remover {quantidade} de {produto} do estoque.')

    def vender_produto(self, produto, quantidade):
        if produto in self.estoque and self.estoque[produto] >= quantidade:
            self.estoque[produto] -= quantidade
            self.vendas += quantidade
            print(f'Vendido {quantidade} de {produto}.')
        else:
            print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        total = sum(self.estoque.values())
        print(f'Total de produtos em estoque: {total}')

    def total_vendas(self):
        print(f'Total de produtos vendidos: {self.vendas}')


sistema = SistemaVendas()
sistema.adicionar_produto('manga', 100)
sistema.vender_produto('manga', 50)
sistema.total_estoque()
sistema.total_vendas()
# Out:
# Adicionado 100 de manga ao estoque.
# Vendido 50 de manga.
# Total de produtos em estoque: 50
# Total de produtos vendidos: 50

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque = {}
        self.vendas = 0

    def adicionar_produto(self):
        produto = input('Digite o nome do produto: ')
        quantidade = int(input('Digite a quantidade a ser adicionada ao estoque: '))
        self.estoque[produto] = self.estoque.get(produto, 0) + quantidade
        print(f'Adicionado {quantidade} de {produto} ao estoque.')

    def vender_produto(self):
        produto = input('Digite o nome do produto: ')
        quantidade = int(input('Digite a quantidade a ser vendida: '))
        if produto in self.estoque and self.estoque[produto] >= quantidade:
            self.estoque[produto] -= quantidade
            self.vendas += quantidade
            print(f'Vendido {quantidade} de {produto}.')
        else:
            print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        total = sum(self.estoque.values())
        print(f'Total de produtos em estoque: {total}')

    def total_vendas(self):
        print(f'Total de produtos vendidos: {self.vendas}')

    def executar(self):
        while True:
            print('1: Adicionar produto ao estoque')
            print('2: Vender produto')
            print('3: Ver total do estoque')
            print('4: Ver total de vendas')
            print('5: Sair')
            opcao = input('Escolha uma opção: ')
            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.vender_produto()
            elif opcao == '3':
                self.total_estoque()
            elif opcao == '4':
                self.total_vendas()
            elif opcao == '5':
                break
            else:
                print('Opção inválida. Tente novamente.')

sistema = SistemaVendas()
sistema.executar()
# Out:
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  5

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque = {}
        self.vendas = 0

    def adicionar_produto(self):
        produto = input('Digite o nome do produto: ')
        quantidade = int(input('Digite a quantidade a ser adicionada ao estoque: '))
        self.estoque[produto] = self.estoque.get(produto, 0) + quantidade
        print(f'Adicionado {quantidade} de {produto} ao estoque.')

    def vender_produto(self):
        produto = input('Digite o nome do produto: ')
        quantidade = int(input('Digite a quantidade a ser vendida: '))
        if produto in self.estoque and self.estoque[produto] >= quantidade:
            self.estoque[produto] -= quantidade
            self.vendas += quantidade
            print(f'Vendido {quantidade} de {produto}.')
        else:
            print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        print('| Produto | Quantidade |')
        print('|---------|------------|')
        for produto, quantidade in self.estoque.items():
            print(f'| {produto} | {quantidade} |')

    def total_vendas(self):
        print(f'Total de produtos vendidos: {self.vendas}')

    def executar(self):
        while True:
            print('1: Adicionar produto ao estoque')
            print('2: Vender produto')
            print('3: Ver total do estoque')
            print('4: Ver total de vendas')
            print('5: Sair')
            opcao = input('Escolha uma opção: ')
            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.vender_produto()
            elif opcao == '3':
                self.total_estoque()
            elif opcao == '4':
                self.total_vendas()
            elif opcao == '5':
                break
            else:
                print('Opção inválida. Tente novamente.')


sistema = SistemaVendas()
sistema.executar()
# Out:
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  sair
# Opção inválida. Tente novamente.
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  sair
# Opção inválida. Tente novamente.
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  5

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque = {}
        self.vendas = 0
        self.tipos = {}

    def adicionar_produto(self):
        produto = input('Digite o nome do produto: ')
        tipo = input('Digite o tipo do produto: ')
        quantidade = int(input('Digite a quantidade a ser adicionada ao estoque: '))
        self.estoque[produto] = self.estoque.get(produto, 0) + quantidade
        self.tipos[produto] = tipo
        print(f'Adicionado {quantidade} de {produto} ({tipo}) ao estoque.')

    def vender_produto(self):
        produto = input('Digite o nome do produto: ')
        quantidade = int(input('Digite a quantidade a ser vendida: '))
        if produto in self.estoque and self.estoque[produto] >= quantidade:
            self.estoque[produto] -= quantidade
            self.vendas += quantidade
            print(f'Vendido {quantidade} de {produto} ({self.tipos[produto]}).')
        else:
            print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        print('| Produto | Tipo | Quantidade |')
        print('|---------|------|------------|')
        for produto, quantidade in self.estoque.items():
            print(f'| {produto} | {self.tipos[produto]} | {quantidade} |')

    def total_vendas(self):
        print(f'Total de produtos vendidos: {self.vendas}')

    def executar(self):
        while True:
            print('1: Adicionar produto ao estoque')
            print('2: Vender produto')
            print('3: Ver total do estoque')
            print('4: Ver total de vendas')
            print('5: Sair')
            opcao = input('Escolha uma opção: ')
            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.vender_produto()
            elif opcao == '3':
                self.total_estoque()
            elif opcao == '4':
                self.total_vendas()
            elif opcao == '5':
                break
            else:
                print('Opção inválida. Tente novamente.')

sistema = SistemaVendas()
sistema.executar()
# Out:
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  5

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque_minimo = {
            'alimentos': 50,
            'bebidas': 75,
            'limpeza': 30
        }
        self.estoque_atual = {}
        self.categorias_produto = {}
        self.vendas = 0

    def adicionar_produto(self):
        produto = input('Digite o nome do produto: ')
        while True:
            categoria = input('Digite a categoria do produto: ')
            if categoria not in self.estoque_minimo:
                print('Categoria inválida. As categorias válidas são: alimentos, bebidas, limpeza.')
            else:
                break
        while True:
            quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')
            try:
                quantidade = int(quantidade)
                break
            except ValueError:
                print('Quantidade inválida. Por favor, insira um número inteiro.')
        if produto in self.categorias_produto:
            print(f'O produto {produto} já está cadastrado na categoria {self.categorias_produto[produto]}. Adicionando à categoria existente.')
            categoria = self.categorias_produto[produto]
        self.estoque_atual[produto] = self.estoque_atual.get(produto, 0) + quantidade
        self.categorias_produto[produto] = categoria
        if self.estoque_atual[produto] < self.estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {self.estoque_atual[produto]} unidades em estoque.')

    def vender_produto(self):
        produto = input('Digite o nome do produto: ')
        quantidade = int(input('Digite a quantidade a ser vendida: '))
        if produto in self.estoque_atual and self.estoque_atual[produto] >= quantidade:
            self.estoque_atual[produto] -= quantidade
            self.vendas += quantidade
            print(f'Vendido {quantidade} de {produto}.')
        else:
            print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        print('| Produto | Quantidade | Categoria |')
        print('|---------|------------|-----------|')
        for produto, quantidade in self.estoque_atual.items():
            print(f'| {produto} | {quantidade} | {self.categorias_produto[produto]} |')

    def total_vendas(self):
        print(f'Total de produtos vendidos: {self.vendas}')

    def executar(self):
        while True:
            print('1: Adicionar produto ao estoque')
            print('2: Vender produto')
            print('3: Ver total do estoque')
            print('4: Ver total de vendas')
            print('5: Sair')
            opcao = input('Escolha uma opção: ')
            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.vender_produto()
            elif opcao == '3':
                self.total_estoque()
            elif opcao == '4':
                self.total_vendas()
            elif opcao == '5':
                break
            else:
                print('Opção inválida. Tente novamente.')

sistema = SistemaVendas()
sistema.executar()
# Out:
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  5

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque_minimo = {
            'alimentos': 50,
            'bebidas': 75,
            'limpeza': 30
        }
        self.estoque_atual = {}
        self.categorias_produto = {}
        self.precos_unitarios = {}
        self.vendas = 0

    def adicionar_produto(self):
        produto = input('Digite o nome do produto: ')
        while True:
            categoria = input('Digite a categoria do produto: ')
            if categoria not in self.estoque_minimo:
                print('Categoria inválida. As categorias válidas são: alimentos, bebidas, limpeza.')
            else:
                break
        preco_unitario = float(input('Digite o preço unitário do produto: '))
        while True:
            quantidade = input('Digite a quantidade a ser adicionada ao estoque: ')
            try:
                quantidade = int(quantidade)
                break
            except ValueError:
                print('Quantidade inválida. Por favor, insira um número inteiro.')
        if produto in self.categorias_produto:
            print(f'O produto {produto} já está cadastrado na categoria {self.categorias_produto[produto]}. Adicionando à categoria existente.')
            categoria = self.categorias_produto[produto]
        self.estoque_atual[produto] = self.estoque_atual.get(produto, 0) + quantidade
        self.categorias_produto[produto] = categoria
        self.precos_unitarios[produto] = preco_unitario
        if self.estoque_atual[produto] < self.estoque_minimo.get(categoria, 0):
            print(f'Solicitar {produto} à equipe de compras, temos apenas {self.estoque_atual[produto]} unidades em estoque.')

    def vender_produto(self):
        produto = input('Digite o nome do produto: ')
        quantidade = int(input('Digite a quantidade a ser vendida: '))
        if produto in self.estoque_atual and self.estoque_atual[produto] >= quantidade:
            self.estoque_atual[produto] -= quantidade
            self.vendas += quantidade * self.precos_unitarios[produto]
            print(f'Vendido {quantidade} de {produto}.')
        else:
            print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        print('| Produto | Quantidade | Categoria | Preço Unitário | Valor Total |')
        print('|---------|------------|-----------|----------------|-------------|')
        for produto, quantidade in self.estoque_atual.items():
            valor_total = quantidade * self.precos_unitarios[produto]
            print(f'| {produto} | {quantidade} | {self.categorias_produto[produto]} | {self.precos_unitarios[produto]} | {valor_total} |')

    def total_vendas(self):
        print(f'Total de produtos vendidos: {self.vendas}')

    def executar(self):
        while True:
            print('1: Adicionar produto ao estoque')
            print('2: Vender produto')
            print('3: Ver total do estoque')
            print('4: Ver total de vendas')
            print('5: Sair')
            opcao = input('Escolha uma opção: ')
            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.vender_produto()
            elif opcao == '3':
                self.total_estoque()
            elif opcao == '4':
                self.total_vendas()
            elif opcao == '5':
                break
            else:
                print('Opção inválida. Tente novamente.')

sistema = SistemaVendas()
sistema.executar()
# Out:
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  sair
# Opção inválida. Tente novamente.
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  5

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque_minimo = {
            'alimentos': 50,
            'bebidas': 75,
            'limpeza': 30
        }
        self.estoque_atual = {}
        self.categorias_produto = {}
        self.precos_unitarios = {}
        self.vendas = 0

    def adicionar_produto(self):
        while True:
            produto = input('Digite o nome do produto ou "sair" para voltar ao menu: ')
            if produto.lower() == 'sair':
                break
            categoria = input('Digite a categoria do produto: ')
            preco_unitario = float(input('Digite o preço unitário do produto: '))
            quantidade = int(input('Digite a quantidade a ser adicionada ao estoque: '))
            if produto in self.categorias_produto:
                print(f'O produto {produto} já está cadastrado na categoria {self.categorias_produto[produto]}. Adicionando à categoria existente.')
                categoria = self.categorias_produto[produto]
            self.estoque_atual[produto] = self.estoque_atual.get(produto, 0) + quantidade
            self.categorias_produto[produto] = categoria
            self.precos_unitarios[produto] = preco_unitario
            if self.estoque_atual[produto] < self.estoque_minimo.get(categoria, 0):
                print(f'Solicitar {produto} à equipe de compras, temos apenas {self.estoque_atual[produto]} unidades em estoque.')

    def vender_produto(self):
        while True:
            produto = input('Digite o nome do produto ou "sair" para voltar ao menu: ')
            if produto.lower() == 'sair':
                break
            quantidade = int(input('Digite a quantidade a ser vendida: '))
            if produto in self.estoque_atual and self.estoque_atual[produto] >= quantidade:
                self.estoque_atual[produto] -= quantidade
                self.vendas += quantidade * self.precos_unitarios[produto]
                print(f'Vendido {quantidade} de {produto}.')
            else:
                print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        print('| Produto | Quantidade | Categoria | Preço Unitário | Valor Total |')
        print('|---------|------------|-----------|----------------|-------------|')
        for produto, quantidade in self.estoque_atual.items():
            valor_total = quantidade * self.precos_unitarios[produto]
            print(f'| {produto} | {quantidade} | {self.categorias_produto[produto]} | {self.precos_unitarios[produto]} | {valor_total} |')

    def total_vendas(self):
        print(f'Total de produtos vendidos: {self.vendas}')

    def executar(self):
        while True:
            print('1: Adicionar produto ao estoque')
            print('2: Vender produto')
            print('3: Ver total do estoque')
            print('4: Ver total de vendas')
            print('5: Sair')
            opcao = input('Escolha uma opção: ')
            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.vender_produto()
            elif opcao == '3':
                self.total_estoque()
            elif opcao == '4':
                self.total_vendas()
            elif opcao == '5':
                break
            else:
                print('Opção inválida. Tente novamente.')

sistema = SistemaVendas()
sistema.executar()
# Out:
# 1: Adicionar produto ao estoque
# 2: Vender produto
# 3: Ver total do estoque
# 4: Ver total de vendas
# 5: Sair
# Escolha uma opção:  5

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque_minimo = {
            'alimentos': 50,
            'bebidas': 75,
            'limpeza': 30
        }
        self.estoque_atual = {}
        self.categorias_produto = {}
        self.precos_unitarios = {}
        self.vendas = {}
        self.total_vendas = 0

    def adicionar_produto(self):
        while True:
            produto = input('Digite o nome do produto ou "sair" para voltar ao menu: ')
            if produto.lower() == 'sair':
                break
            categoria = input('Digite a categoria do produto: ')
            preco_unitario = float(input('Digite o preço unitário do produto: '))
            quantidade = int(input('Digite a quantidade a ser adicionada ao estoque: '))
            if produto in self.categorias_produto:
                print(f'O produto {produto} já está cadastrado na categoria {self.categorias_produto[produto]}. Adicionando à categoria existente.')
                categoria = self.categorias_produto[produto]
            self.estoque_atual[produto] = self.estoque_atual.get(produto, 0) + quantidade
            self.categorias_produto[produto] = categoria
            self.precos_unitarios[produto] = preco_unitario
            if self.estoque_atual[produto] < self.estoque_minimo.get(categoria, 0):
                print(f'Solicitar {produto} à equipe de compras, temos apenas {self.estoque_atual[produto]} unidades em estoque.')

    def vender_produto(self):
        while True:
            produto = input('Digite o nome do produto ou "sair" para voltar ao menu: ')
            if produto.lower() == 'sair':
                break
            quantidade = int(input('Digite a quantidade a ser vendida: '))
            if produto in self.estoque_atual and self.estoque_atual[produto] >= quantidade:
                self.estoque_atual[produto] -= quantidade
                self.vendas[produto] = self.vendas.get(produto, 0) + quantidade
                self.total_vendas += quantidade * self.precos_unitarios[produto]
                print(f'Vendido {quantidade} de {produto}.')
            else:
                print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        print('| Produto | Quantidade | Categoria | Preço Unitário | Valor Total |')
        print('|---------|------------|-----------|----------------|-------------|')
        for produto, quantidade in self.estoque_atual.items():
            valor_total = quantidade * self.precos_unitarios[produto]
            print(f'| {produto} | {quantidade} | {self.categorias_produto[produto]} | {self.precos_unitarios[produto]} | {valor_total} |')

    def total_vendas(self):
        print('| Produto | Quantidade Vendida |')
        print('|---------|--------------------|')
        for produto, quantidade in self.vendas.items():
            print(f'| {produto} | {quantidade} |')
        print(f'Total de vendas: {self.total_vendas}')

    def executar(self):
        while True:
            print('1: Adicionar produto ao estoque')
            print('2: Vender produto')
            print('3: Ver total do estoque')
            print('4: Ver total de vendas')
            print('5: Sair')
            opcao = input('Escolha uma opção: ')
            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.vender_produto()
            elif opcao == '3':
                self.total_estoque()
            elif opcao == '4':
                self.total_vendas()
            elif opcao == '5':
                break
            else:
                print('Opção inválida. Tente novamente.')

sistema = SistemaVendas()
sistema.executar
# Out:
# <bound method SistemaVendas.executar of <__main__.SistemaVendas object at 0x000001C638FBB990>>

# %%
class SistemaVendas:
    def __init__(self):
        self.estoque_minimo = {
            'alimentos': 50,
            'bebidas': 75,
            'limpeza': 30
        }
        self.estoque_atual = {}
        self.categorias_produto = {}
        self.precos_unitarios = {}
        self.vendas = {}
        self.total_vendas = 0

    def adicionar_produto(self):
        while True:
            produto = input('Digite o nome do produto ou "sair" para voltar ao menu: ')
            if produto.lower() == 'sair':
                break
            categoria = input('Digite a categoria do produto: ')
            preco_unitario = float(input('Digite o preço unitário do produto: '))
            quantidade = int(input('Digite a quantidade a ser adicionada ao estoque: '))
            if produto in self.categorias_produto:
                print(f'O produto {produto} já está cadastrado na categoria {self.categorias_produto[produto]}. Adicionando à categoria existente.')
                categoria = self.categorias_produto[produto]
            self.estoque_atual[produto] = self.estoque_atual.get(produto, 0) + quantidade
            self.categorias_produto[produto] = categoria
            self.precos_unitarios[produto] = preco_unitario
            if self.estoque_atual[produto] < self.estoque_minimo.get(categoria, 0):
                print(f'Solicitar {produto} à equipe de compras, temos apenas {self.estoque_atual[produto]} unidades em estoque.')

    def vender_produto(self):
        while True:
            produto = input('Digite o nome do produto ou "sair" para voltar ao menu: ')
            if produto.lower() == 'sair':
                break
            quantidade = int(input('Digite a quantidade a ser vendida: '))
            if produto in self.estoque_atual and self.estoque_atual[produto] >= quantidade:
                self.estoque_atual[produto] -= quantidade
                self.vendas[produto] = self.vendas.get(produto, 0) + quantidade
                self.total_vendas += quantidade * self.precos_unitarios[produto]
                print(f'Vendido {quantidade} de {produto}.')
            else:
                print(f'Produto {produto} não disponível em quantidade suficiente para venda.')

    def total_estoque(self):
        print('| Produto | Quantidade | Categoria | Preço Unitário | Valor Total |')
        print('|---------|------------|-----------|----------------|-------------|')
        for produto, quantidade in self.estoque_atual.items():
            valor_total = quantidade * self.precos_unitarios[produto]
            print(f'| {produto} | {quantidade} | {self.categorias_produto[produto]} | {self.precos_unitarios[produto]} | {valor_total} |')

    def total_vendas(self):
        print('| Produto | Quantidade Vendida |')
        print('|---------|--------------------|')
        for produto, quantidade in self.vendas.items():
            print(f'| {produto} | {quantidade} |')
        print(f'Total de vendas: {self.total_vendas}')

    def executar(self):
        while True:
            print('1: Adicionar produto ao estoque')
            print('2: Vender produto')
            print('3: Ver total do estoque')
            print('4: Ver total de vendas')
            print('5: Sair')
            opcao = input('Escolha uma opção: ')
            if opcao == '1':
                self.adicionar_produto()
            elif opcao == '2':
                self.vender_produto()
            elif opcao == '3':
                self.total_estoque()
            elif opcao == '4':
                self.total_vendas()
            elif opcao == '5':
                break
            else:
                print('Opção inválida. Tente novamente.')

sistema = SistemaVendas()
sistema.executar
# Out:
# <bound method SistemaVendas.executar of <__main__.SistemaVendas object at 0x000001C638FC6450>>
